# %%
import pandas as pd

# %%
data = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]] ,columns=["A","B","C"] ,index= ["D","E","F"])

# %%
#printimg whole dataframe
data
# Out:
#    A  B  C
# D  1  2  3
# E  4  5  6
# F  7  8  9

# %%
#printing only columns
data.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
#only index
data.index
# Out:
# Index(['D', 'E', 'F'], dtype='object')

# %%
#printing 1st index
data.head(1)
# Out:
#    A  B  C
# D  1  2  3

# %%
#printing last index
data.tail(1)
# Out:
#    A  B  C
# F  7  8  9

# %%
data.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, D to F
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
#size of the data
data.size
# Out:
# 9

# %%
#shape of the data
data.shape
# Out:
# (3, 3)

# %%
#printing a specific column
data["A"]
# Out:
# D    1
# E    4
# F    7
# Name: A, dtype: int64

# %%
#unique value in specific column
data["B"].unique()
# Out:
# array([2, 5, 8])

# %%
#printing no. of unique values in
data.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64
